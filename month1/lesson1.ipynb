# %%
print('Мы изучаем питон')
# Out:
# Мы изучаем питон

# %%
print('Я', 'учусь', 'программировать', 'на', 'питоне')
# Out:
# Я учусь программировать на питоне

# %%
print('В тексте есть "двойные" ковычки')
# Out:
# В тексте есть "двойные" ковычки

# %%
print("В тексте есть 'одинарные' ковычки",input())
# Out:
# В тексте есть 'одинарные' ковычки

# %%
a = input()
b = input()vcc
c = input()
print(a,b,c)

# %%
print('aa', 'bb','cc',sep='*' )
# Out:
# aa*bb*cc

# %%
print('Великий лидек не говорит об этой',end = '\n')
print('Он Знает это',end='\n')
# Out:
# Великий лидек не говорит об этой
# Он Знает это

# %%
minus = '-'
print('a','b','c',end = minus)
print('second line')
# Out:
# a b c-second line

# %%
print('Yes',sep='!',end='#')
print('No',sep='#', end='!')
# Out:
# Yes#No!

# %%
sep1 = '#'
end2 = '?'
print('YES', 'NO', sep=sep1, end='+')
print('MAYBE', 'NEVER', sep='*', end=end2)
# Out:
# YES#NO+MAYBE*NEVER?

# %%
print('БЕСКОНЕЧНОСТЬ', 'НЕ', 'ПРЕДЕЛ', '!', sep='_')
# Out:
# БЕСКОНЕЧНОСТЬ_НЕ_ПРЕДЕЛ_!

# %%
print('БЕСКОНЕЧНОСТЬ_НЕ_ПРЕДЕЛ!')
# Out:
# БЕСКОНЕЧНОСТЬ_НЕ_ПРЕДЕЛ!

# %%
print('БЕСКОНЕЧНОСТЬ', 'НЕ', 'ПРЕДЕЛ!', sep='_', end='!')
# Out:
# БЕСКОНЕЧНОСТЬ_НЕ_ПРЕДЕЛ!!

# %%
print('БЕСКОНЕЧНОСТЬ', 'НЕ', 'ПРЕДЕЛ', sep='_', end='')
print('!')
# Out:
# БЕСКОНЕЧНОСТЬ_НЕ_ПРЕДЕЛ!

# %%
print('БЕСКОНЕЧНОСТЬ_НЕ_ПРЕДЕЛ', end='')
print('!')
# Out:
# БЕСКОНЕЧНОСТЬ_НЕ_ПРЕДЕЛ!

# %%
print('БЕСКОНЕЧНОСТЬ_', 'НЕ_', 'ПРЕДЕЛ!', sep='', end='')
# Out:
# БЕСКОНЕЧНОСТЬ_НЕ_ПРЕДЕЛ!

# %%
print('I', 'like', 'Python',sep='***')
# Out:
# I***like***Python

# %%
name, surname= ' Timur', 'Guev'
print('Имя:',name,'Фамилия:',surname)
# Out:
# Имя:  Timur Фамилия: Guev

# %%
name, surname= input(),input(_)
print('Имя:',name,'Фамилия:',surname)
# Out:
# Имя:  Фамилия: 1

# %%
s = '19990'
year = int(s)
print(year)
# Out:
# 19990

# %%
num1 = input()
num2 = input()
print(num1+num2)
# Out:
# чы

# %%
num = 17
s = str(num)

# %%
num = -6
num2 = -17 +7
print(num)
print(num2)
# Out:
# -6
# -10

# %%
a = 7
b = -3

print(-a+b+7)
print(a+2*b)
print(-a+b+3)
print((a+b)/4)
print((a+2)/b)
# Out:
# -3
# 1
# -7
# 1.0
# -3.0

# %%
s = 0
k  = 30
d = k -5
k = 2 *d
s = k -100

print(s)
# Out:
# -50

# %%
x = 3
y = 4
z = x +y 
print (z)
z= z+1
print (z)
x = y 
print(x)
y = 5
print(x)
x= z+y+7
print(x)
# Out:
# 7
# 8
# 4
# 4
# 20

# %%
a = 4
print(a)
# Out:
# 4

# %%
a = int(input())
print(a)
print(a+1)
print(a+2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 a = int(input())
#       2 print(a)
#       3 print(a+1)
#
# ValueError: invalid literal for int() with base 10: 'ы'

# %%
a = int(input())
b = int (input())
c = int (input())
print(a+b+c)
# Out:
# 21

# %%
a = int(input())
b = int (input())
c = int (input())
d = int(input())
print(a+b+c+d)
# Out:
# 72489

# %%
monitor = int(input())
system_block = int(input())
keybord = int(input())
mouse = int(input())


one_pc = monitor + system_block + keybord + mouse
total = one_pc * 3
print(total)
# Out:
# 12

# %%
a = int(input())
b = int(input())
ab = a + b 
a_qub = ab * ab * ab 
b_sq = b * b 
total = 3 * a_qub + 275 * b_sq - 127*a -41
print(total)
# Out:
# 131

# %%
a = int(input())
num1 = a + 1
num = a - 1
print('Следующее за числом',a,'число:',num1 )
print('Следующее за числом',a,'предыдущее число:',num )
# Out:
# Следующее за числом 20 число: 21
# Следующее за числом 20 предыдущее число: 19

# %%
a = int(input())
v = a * a * a
S = 6 * a * a 
print('Объем =', v)
print('Площадь полной поверхности =', S)
# Out:
# Объем = 15625
# Площадь полной поверхности = 3750

# %%
a = int(input())
b =  int(input())

print(a, '+', b, '=',a+b)
print(a, '-', b, '=',a-b)
print(a, '*', b, '=',a*b)
# Out:
# 2 + 7 = 9
# 2 - 7 = -5
# 2 * 7 = 14

# %%
a = int(input())
d = int(input())
n = int(input())
total =  a*1 + d*(n-1)
print(total)
# Out:
# 10

# %%
a = int(input())
print(a, 2*a, 3*a, 4*a, 5*a, sep='---')
# Out:
# 7---14---21---28---35

# %%
print(10 % 3)
# Out:
# 1

# %%
# 84 // 12
18 % 12
# Out:
# 6

# %%
print(3**1**2)
# Out:
# 3

# %%
a = 15// (16 % 7)


b = 34 % a * 5 - 29 % 5 *2
print(a+b)
# Out:
# 29

# %%
a = 82 // 3**2 % 7
print(a)
# Out:
# 2

# %%
b = int(input())
q = int (input())
n = int(input())



total = b * 1 * q ** (n-1)
print(total)
# Out:
# 16

# %%
q  = int(input())
pl = q // 100
print(pl)
# Out:
# 3

# %%
shkoolboys = int(input())
mandarins = int (input())

mandarin_full = mandarins // shkoolboys
mandarin_rema = mandarins % shkoolboys
print(mandarin_full)
print(mandarin_rema)
# Out:
# 2
# 0

# %%
peaple = int(input())
lost = (peaple +1)// 2
print(lost)
# Out:
# 50

# %%
minutes = int(input())
hour = minutes // 60 
half_hour = minutes % 60

print(minutes, 'мин - это', hour, 'час', half_hour, 'минут.')
# Out:
# 150 мин - это 2 час 30 минут.

# %%
place = int(input())
com = (place + 3)//4
print(com)
# Out:
# 6

# %%
num = 17
a = num % 10             # вычисляем последнюю цифру числа
b = num // 10            # вычисляем первую цифру числа

print(a)
print(b)
# Out:
# 7
# 1

# %%
a = int(input())
first_num = a // 100 
second = (a % 100) // 10
pos_num = a % 10
sum = first_num + second + pos_num
proiz = first_num * second * pos_num
print('Сумма цифр =',sum )
print('Произведение цифр =', proiz)
# Out:
# Сумма цифр = 6
# Произведение цифр = 6

# %%
p = int(input())

a = p // 100
b = (p% 100) // 10
c = p % 10

print(a,b,c, sep ='')
print(a,c,b, sep ='')
print(b,a,c, sep ='')
print(b,c,a, sep ='')
print(c,a,b, sep ='')
print(c,b,a, sep ='')
# Out:
# 123
# 132
# 213
# 231
# 312
# 321

# %%
p = int(input())

d = p // 100 // 10
a = p // 100 % 10
b = (p% 100) // 10
c = p % 10

print('Цифра в позиции тысяч равна', d)
print('Цифра в позиции сотен равна', a)
print('Цифра в позиции десятков равна', b)
print('Цифра в позиции единиц равна', c)
# Out:
# Цифра в позиции тысяч равна 3
# Цифра в позиции сотен равна 2
# Цифра в позиции десятков равна 8
# Цифра в позиции единиц равна 1

# %%
a = 17 // (23 % 7)
b = 34 % a * 5 - 29 % 4 * 3
print(a * b)
# Out:
# 56

# %%
print('*' * 17)
print('*' + ' ' * 15 + '*')
print('*' + ' ' * 15 + '*')
print('*' * 17)
# Out:
# *****************
# *               *
# *               *
# *****************

# %%
word = input()
if word == 'Python':
    print('ДА')
else:
    print('Нет')
# Out:
# ДА

# %%
num = int(input())
firs = num //10
print(firs)

# %%
i = int(input())
if i / 2:
    print(i, 'четное')
else:
    print('нечетное')
# Out:
# 3 четное

# %%
a = (input())
b = (input())
if a == b:
    print('Пароль принят')
else:
    print('Пароль не принят')
# Out:
# Пароль не принят

# %%
n = int(input())
if n % 2 == 0:
    print('Четное')
else:
    print('Нечетное')
# Out:
# Нечетное

# %%
n = int(input())
a = n // 100 // 10
b = n // 100 % 10 
c = n // 10 % 10 
d = n % 10 
sum_a_d = a + d
raz_b_c = b - c



if sum_a_d == raz_b_c:
    print('ДА')
else:
    print('НЕТ')
# Out:
# ДА

# %%
n = int(input())
if n >= 18:
    print('Доступ разрешен')
else:
    print('Доступ запрещен')
# Out:
# Доступ запрещен

# %%
a = int(input())
b = int(input())
c = int(input())

if a - b == b-c:
    print('YES')
else:
    print('NO')
# Out:
# YES

# %%
a = int(input())
b = int(input())

if a < b:
    print(a)
else:
    print(b)
# Out:
# 8

# %%
n = int(input())
if n <= 13:
    print('детство')
if  14 <= n <= 24:
    print('молодость')
if 25 <= n <= 59:
    print('зрелость')
if 60 <= n:
    print('старость')
# Out:
# детсво

# %%
num1 = 34
num2 = 81
if num1 // 9 == 0 or num2 % 9 == 0:
    print('число', num1, 'выиграло')
else:
    print('число', num2, 'выиграло')
# Out:
# число 34 выиграло

# %%
num2 = 81
34 // 9
print(num1)
# Out:
# 34

# %%
a = int(input())

if a >= 2 and a <= 17:
    b = 3
    p = a * a + b * b
else:
    b = 5

p = (a + b) * (a + b)
print(p)
# Out:
# 100

# %%
n = int(input())

if -1 < n < 17:
    print('Принадлежит')
else: 
    print('Не принадлежит')
# Out:
# Принадлежит

# %%
n = int(input())

if   n <= -3 or  n >= 7:
    print('Принадлежит')
else:

    print('Не принадлежит')
# Out:
# Принадлежит

# %%
n = int(input())
if (-30 < n <= -2 ) or (7 < n <=25  ): 
    print('Принадлежит')
else:
    print('Не принадлежит')
# Out:
# Не принадлежит

# %%
n = int(input())
if (9999 >= n >= 1000) and (n % 7 == 0 or n % 17 ==0):
    print('YES')
else: print('NO')
# Out:
# YES

# %%
a = int(input())
b = int(input())
c = int(input())

if a +b > c and a+c > b and c + b > a:
    print('YES')
else:
    print('NO')
# Out:
# NO

# %%
n = int(input())
if (400 % 4 == 0)or (n % 4 == 0 and n %100 !=0):  
    print('YES')
else: 
    print('NO')
# Out:
# YES

# %%
a = int(input())
b = int(input())
c = int(input())
d = int(input())

# %%
grade = int(input('Введите вашу отметку по 100-балльной системе: '))

if grade >= 90:
    print(5)
else:
    if grade >= 80:
        print(4)
    else:
        if grade >= 70: 
            print(3)
        else:
            if grade >= 60:
                print(2)
            else:
                print(1)
# Out:
# 1

# %%
n, k  = int(input()), int(input())
if n > k:
    print('NO')
elif n < k:
    print('YES')
elif n==k:
    print("Don't know")
# Out:
# NO

# %%
a, b, c = int(input()), int(input()), int(input())

if a == b == c:
    print('Равносторонний')
elif a == b or a == c or b == c:
    print('Равнобедренный')
else:
    print('Разносторонний')
# Out:
# Равнобедренный

# %%
a, b, c, = int(input()), int(input()), int(input())

if a < b < c or c < b < a:
    print('b')
elif b < a < c or c < a < b:
    print('a')
else:
    print(c)
# Out:
# b

# %%
m = int(input())

if m == 2:
    print('12')
elif (m == 4) or (m == 6) or (m == 9) or (m ==11):
    print(30)
else: 
    print(31)
# Out:
# 31

# %%
w = int(input())
if w < 60:
    print('Легкий вес')
elif 60 <= w < 64:
    print('Первый полусредний вес')
elif 64 <= w < 69:
    print('Полусредний вес')
# Out:
# Легкий вес

# %%
a = int(input())
b = int(input())
c = (input())

if c == '+':
    print(a+b)
elif c == '-':
    print(a-b)
elif c == '*':
    print(a*b)
elif (b == 0) and (c == '/'):
    print('На ноль делить нельзя!')
elif c == '/':
    print(a / b)
else:
    print('Неверная операция')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[169], line 1
# ----> 1 a = int(input())
#       2 b = int(input())
#       3 c = (input())
#
# ValueError: invalid literal for int() with base 10: ''

# %%
c1 = input()
c2 = input()

if (c1 != 'красный' and c1 != 'желтый' and c1 != 'синий') or (c2 != 'красный' and c2 != 'желтый' and c2 !='синий'):
    print('ошибка цвета')
elif (c1 == 'красный' and c2 == 'синий') or (c1=='синий' and c2 =='красный'):
    print('фиолетовый')
elif c1==c2:
    print(c1)
elif (c1 == 'красный' and c2 == 'желтый') or (c1 == 'желтый' and c2 == 'красный'):
    print('оранжевый')
elif (c1 == 'желтый' and c2 == 'синий') or (c1 == 'синий' and c2 == 'желтый'):
    print('зеленый')
# Out:
# красный

# %%
n = int(input())
if n < 0 or n > 36:
    print('ошибка ввода')
elif n == 0:
    print('зеленый')
elif 1 <= n <= 10:
    if n % 2 == 0:
        print('черный')
    else:
        print('красный')
elif 11 <= n <= 18:
    if n % 2 == 0:
        print('черный')
    else:
        print('красный')
elif 19 <= n <=28:
    if n % 2 == 0:
        print('черный')
    else:
        print('красный')
elif 29 <= n <=36:
    if n % 2 == 0:
        print('черный')
    else:
        print('красный')

# %%
n = int(input())

n2 = n % 10
n3 = n % 100 %10

if (n2 == 0) and (n3==0):
    print('YES')
else:
    print('NO')
# Out:
# NO

# %%
a = float(input())
b = float (input())

n = 0.5 * a * b 
print(n)

# %%
s = float(input())
v1 = float(input())
v2 = float(input())

t = s / (v1 + v2)
print(t)
# Out:
# 2.0

# %%
n = float(input())

if n == 0:
    print('Обратного числа не существует')
else:
   print (1 / n)
# Out:
# 0.4

# %%
n = float(input())

t1c = 5/9 * (n-32)
print(t1c)
# Out:
# 232.5277777777778

# %%
n = float(input())

if n == 1:
    print('10.5')
elif n == 2:
    print('21')
else:
    print(21 +(n-2)*4)
# Out:
# 10.5

# %%
n = float(input())

dig = int(n*10)
print(dig)
# Out:
# 3384390

# %%
x = float(input())
fraction = x - int(x)
print(fraction)
# Out:
# 0.45000000000000284

# %%
num = max(1, 3, -5, 7) + min (-3, 6, -8, -1) +abs(-17)
print(num)
# Out:
# 16

# %%
a, b, c, d, s = int(input()), int(input()), int(input()), int(input()), int(input())
maxche = max(a, b, c, d, s)
minche = min(a, b, c, d, s)
print('Наименьшее число =', minche)
print('Наибольшее число =', maxche)
# Out:
# Наименьшее число = 5
# Наибольшее число = 1

# %%
a, b, c = int(input()), int(input()), int(input())

num1 = max(a, b, c)
num2 = min (a, b, c)
num3 = a + b + c - num1-num2
print(num1, num2, num3)
# Out:
# 135 129 132

# %%
n  = int(input())

num1 = n // 100 % 10
avr = n // 10 %10
num3 = n % 10
maxnum = max(num1, avr, num3)
minnum = min(num1, avr, num3)
raz = maxnum - minnum
avrnum = avrnum = num1 + avr + num3 - maxnum - minnum

if avrnum == raz:
    print('Число интересное')
else:
    print('Число неинтересное')
# Out:
# Число неинтересное

# %%
a, b, c, d, f = float(input()), float(input()), float(input()), float(input()), float(input())
total = abs(a)+abs(b)+abs(c)+abs(d)+abs(f)
print(total)
# Out:
# 1280.289

# %%
p1, p2, q1, q2 = int(input()), int(input()), int(input()), int(input())

qwe = abs(p1-q1) + abs(p2-q2)
print(qwe)
# Out:
# 13

# %%
mystr = 'да'
mystr = mystr + 'нет'
mystr = mystr + 'да'
print(mystr)
# Out:
# данетда

# %%
a = str(input())

b = str(input())
print('Hello', a, b+'!', 'You have just delved into Python')
# Out:
# Hello Jon  Hek! You have just delved into Python

# %%
a = str(input())
lenf = len(a)


print('Футбольная команда', a, 'имеет длину', lenf, 'символов')
# Out:
# Футбольная команда Barcelona имеет длину 9 символов

# %%
a, b, c = str(input()), str(input()), str(input())
l1 = len(a)
l2 = len(b)
l3 = len(c)


if (l1 < l2) and (l1 < l3):
    shert  = a
elif (l2 < l1) and l2 < l3:
    shert = b
else:
    shert = c

if (l1 > l2) and (l1 > l3):
    long = a
elif (l2 > l1) and (l2 > l3):
    long =b
else:
    long = c


print(shert)
print(long)
# Out:
# 6 15 12
# Москва
# Санкт-Петербург

# %%
language1 = 'JavaScript'
language2 = 'Java'

print(language1 in language2)
print(language2 in language1)
# Out:
# False
# True

# %%
n = str(input())
w = 'синий'

if w in n:
    print('YES')
else:
    print('NO')
# Out:
# NO

# %%
n = str(input())
sb = 'суббота'
vs = 'воскресенье'

if (sb in n) or (vs in n):
    print('YES')
else:
    print('NO')
# Out:
# NO

# %%
n = str(input())

if ('@' in n) and ('.' in n):
    print('YES')
else:
    print('NO')
# Out:
# NO

# %%
import math

# %%
# Out:
# 1.4142135623730951
# 4
# 3

# %%
from math import * 

x1, y1, x2, y2 = float(input()), float(input()), float(input()), float(input())

tot = sqrt((x1 - x2)**2  + (y1-y2)**2)


print(tot)
# Out:
# 106.68197610187018

# %%
from math import *

R = float(input())

S = pi * R **2
C = 2 * pi *R 
print(S) 
print(C)
# Out:
# 966294.7126386268
# 3484.654571361799

# %%
from math import *

a = float(input())
b = float(input())

avr = (a + b) / 2  
avr1 = sqrt(a * b)
avr2 = (2 * a * b) / (a + b)
avr3 = sqrt((a**2 + b **2)/2)
print(avr)
print(avr1)
print(avr2)
print(avr3)
# Out:
# 1.45
#  1.4491376746189437
#  4.199999999999999
#  1.4508618128546908

# %%
for i in range(5):
    num = int(input())
    print('dsdsd', + num + num + num)
print('цикл')
# Out:
# dsdsd 3
# dsdsd 3
# dsdsd 9
# dsdsd 150
# dsdsd 69
# цикл

# %%
for i in range(10):
    print('Python is awesome!')
# Out:
# Python is awesome!
# Python is awesome!
# Python is awesome!
# Python is awesome!
# Python is awesome!

# %%
for i in range(6):
    print('AAA')
for i in range(5):
    print('BBBB')
print('E')
for i in range(9):
    print('TTTTT')
print('G')
# Out:
# AAA
# AAA
# AAA
# AAA
# AAA
# AAA
# BBBB
# BBBB
# BBBB
# BBBB
# BBBB
# E
# TTTTT
# TTTTT
# TTTTT
# TTTTT
# TTTTT
# TTTTT
# TTTTT
# TTTTT
# TTTTT
# G

# %%
a = str(input())
b = int(input())

for i in range(b):
    print(a)
# Out:
# Век живи - век учись.
# Век живи - век учись.
# Век живи - век учись.
# Век живи - век учись.
# Век живи - век учись.
# Век живи - век учись.
# Век живи - век учись.
# Век живи - век учись.
# Век живи - век учись.
# Век живи - век учись.

# %%
n = int(input())

for i in range(n):
    print('*' * 19)
# Out:
# *******************

# %%
for i in range(10):
    print(i + 1, 'Ghb')
# Out:
# 1 Ghb
# 2 Ghb
# 3 Ghb
# 4 Ghb
# 5 Ghb
# 6 Ghb
# 7 Ghb
# 8 Ghb
# 9 Ghb
# 10 Ghb

# %%
n = str(input())

for i in range(10):
    print(i, n)
# Out:
# 0 LeBron
# 1 LeBron
# 2 LeBron
# 3 LeBron
# 4 LeBron
# 5 LeBron
# 6 LeBron
# 7 LeBron
# 8 LeBron
# 9 LeBron

# %%
n = int(input())

for i in range(n):
    print('Квадрат числа', i, 'равен', i**2 )
# Out:
# Квадрат числа 0 равен  0
# Квадрат числа 1 равен  1
# Квадрат числа 2 равен  4
# Квадрат числа 3 равен  9
# Квадрат числа 4 равен  16
# Квадрат числа 5 равен  25
# Квадрат числа 6 равен  36
# Квадрат числа 7 равен  49
# Квадрат числа 8 равен  64
# Квадрат числа 9 равен  81

# %%
n = int(input())

for i in range(n):
    print('*' * (n-i))
# Out:
# ***
# **
# *

# %%
m = int(input())
p = int(input())
n = int(input())
proc = m * (p / 100)
for i in range( n+1):
    print(i+1, m + p )ы
# Out:
# 1 15.0
# 2 15.0
# 3 15.0
# 4 15.0
# 5 15.0
# 6 15.0
# 7 15.0

# %%
for i in range(5,15 , 2):
    print(i)
# Out:
# 5
# 7
# 9
# 11
# 13

# %%
for i in range(10,0, -2):
    print(i, 'Go go go!')
# Out:
# 10 Go go go!
# 8 Go go go!
# 6 Go go go!
# 4 Go go go!
# 2 Go go go!

# %%
n1 = int(input())
n2 = int(input())

for i in range(n1, n2+1):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
m = int(input())
n = int(input())

if m < n:
    for i in range(m, n+1):
        print(i)
elif m > n:
    for i in range(m, n-1, -1):
        print(i)       
else:
    print(i)
# Out:
# 100

# %%
m = int(input())
n = int(input())

for i in range(m, n+1):
    if (i % 17 == 0 ) or (i % 10 == 9) or (i % 15 ==0):
        print(i)
# Out:
# 9
# 15
# 19

# %%
n = int(input())

for i in range(1,11):
    print(n, 'x', i, '=', n*i)
# Out:
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27

# %%
conret = 0
for _ in range(10):
    num = int(input())
    if num > 10:
        conret = conret +1
print()

# %%
conret = 0
cer = 0
for _ in range(10):
    num = int(input())
    if num > 10:
        conret = conret +1
    if num == 0:
        cer = +1
        
print(conret, cer)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[125], line 4
#       2 cer = 0
#       3 for _ in range(10):
# ----> 4     num = int(input())
#       5     if num > 10:
#       6         conret = conret +1
#
# ValueError: invalid literal for int() with base 10: ''

# %%
n = 0

for i in range(1, 101):
    if i **2 % 10 == 4:
        n = n + 1
print(n)
# Out:
# 20

# %%
#Напишем программу, которая считывает 10 чисел и определяет сумму тех из них, которые больше 10 10.

cnt = 0

for _ in range(10):
    n = int(input())
    if n > 10:
        cnt = cnt + n 
print(cnt )
# Out:
# 35

# %%
total = 0 
for i in range(1, 6):
    total += i
    print(total, end = '')
# Out:
# 1361015

# %%
a = int(input())
b = int(input())

cnt = 0

for i in range(a, b+  1):
    last = (i ** 3) % 10
    if last == 4 or last == 9:
        cnt += 1
print(cnt)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[151], line 1
# ----> 1 a = int(input())
#       2 b = int(input())
#       4 cnt = 0
#
# ValueError: invalid literal for int() with base 10: ''

# %%
n = int(input())
cnt = 0
for i in range(n):
    ter = int(input())
    cnt += ter
print(cnt)
# Out:
# 5

# %%
import math

n = int(input())

cnt = 0 
for i in range(1, n +1):
    cnt += 1 / i
loger = cnt   - math.log(n)
print(loger)
# Out:
# 0.6263831609742079

# %%
n = int(input())

cnt = 0

for i in range (1, n +1):
    if (i ** 2) % 10 == 2 or (i ** 2) % 10   == 5 or (i ** 2) % 10 == 8:
        cnt += i
print(cnt)
# Out:
# 5

# %%
n = int(input())

cnt = 1 

for i in range(1, n+1):
    cnt *= i
print(cnt)
# Out:
# 6

# %%
cnt = 1 
for i in range(10):
    n = int(input())
    if n != 0 :
        cnt *= n
print(cnt)
# Out:
# 3840

# %%
n = int(input())

cnt = 0

for i in range(1, n+1):
    if n % i == 0:
        cnt += i 
print(cnt)
# Out:
# 18

# %%
flag = True

for i in range(10):
    n = int(input())
    if n %2 != 0:
        flag = False
       
       
if flag == True:
    print('YES')
else:
    print('NO')
# Out:
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO
# NO

# %%
n = int(input())
cnt = 0
for i in range(1, n+1):
    if i % 2 == 0:
        cnt -= i
    else:
        cnt +=i
print(cnt)
# Out:
# 1

# %%
n = int(input())
# Out:
# 5 2.5

# %%
n = int(input())

a = int(input())
b = int(input())

if a > b:
    max1 = a
    max2 = b
else:
    max1 = b
    max2 = a

for i in range(n-2):
    n = int(input())
    if n > max1:
        max2 = max1
        max1 = n
    elif n > max2:
        max2 = n

print(max1)
print(max2)

# %%
n = int(input())

a = 1
b = 1

if n == 1:
    print(a)
else:
    print(a, b, " ")
    for i in range(3,n+1):
        a,b = b, a+b
        print(b, end = " ")
# Out:
# 1 1
# 2 3 5

# %%
counter1 = 0
counter2 = 0
for _ in range(10):
    num = int(input())
    if num > 10:
        counter1 = counter1 +1
    if num == 0:
        counter2 = counter2  +1
print('Было введено', counter, 'чилес больше 10')
print('Было введено', counter2, 'нулей.' )
# Out:
# Было введено 5 чилес больше 10
# Было введено 0 нулей.

# %%
maximum = int(input())
for _ in range(4)
num = int(input())

# %%
a = 7 % 2 
print(a)
# Out:
# 1

# %%
counter = 0
for i in range(1, 11):
    if i % 2 == 1:
        counter = counter + 1

print(counter)
ррпр = 1
# Out:
# 5
